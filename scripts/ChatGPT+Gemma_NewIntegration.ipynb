# %% [markdown]
# PAPER: [https://openai.com/api/pricing/]
#
# 1. GPT o4-mini [REASONING MODEL] — https://platform.openai.com/docs/models/o4-mini   DONE ✅
#   **id**: o4-mini-2025-04-16
#   **PRICING** per 1M:
#     Input: 1.10
#     Output: 4.40
#
# 3. GPT-4.1 nano (poeftin) — https://platform.openai.com/docs/models/gpt-4.1-nano  DONE ✅
#   **id**: gpt-4.1-nano-2025-04-14
#   **PRICING** per 1M:
#   Input: 0.10
#   Output:  0.40
#
# 4. Gema [Groq]   DONE ✅
#   **id**:
#   **PRICING** per 1M: FREE with x specific LIMITS

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.84.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
from openai import OpenAI
client = OpenAI(api_key="")

# %%
my_assistant = client.beta.assistants.list()

print(my_assistant.data)
# Out:
# [Assistant(id='asst_IwJsTM0Tgp8RhbFTFwXaKjNj', created_at=1748468183, description=None, instructions="\nImagine you are an employer working as a Project Manager in software company in COUNTRY . You are a typical North Macedonia cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the three given options.\n  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a\n  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.\n  Question 1:When I get really upset, I ...\n  option a: Analyze why I am so disturbed.\n  option b: Blow up and let off steam.\n  option c: Hide it and remain calm.\n  Question 2:In a situation in which a colleague takes credit in public for my work and my ideas,I would probably ...\n  option a: Let it slide and do nothing in order to avoid a confrontation.\n  option b: Later—in private—indicate that I would appreciate being given credit for my work and ideas.\n  option c: Thank the person in public for referencing my work and ideas and then elaborate on my contributions.\n", metadata={}, model='gpt-4.1-nano-2025-04-14', name='EM_assistant', object='assistant', tools=[CodeInterpreterTool(type='code_interpreter')], response_format='auto', temperature=0.0, tool_resources=ToolResources(code_interpreter=ToolResourcesCodeInterpreter(file_ids=[]), file_search=None), top_p=1.0, reasoning_effort=None), Assistant(id='asst_OzTnrR5JZEmUsomNTyyUXSCr', created_at=1743022731, description=None, instructions='\n      You are an AI assistant that answers questions using the perspective of the given persona.\n      You must select the most appropriate answer and provide a concise explanation.\n\n      Follow this format:\n      A) [Chosen answer text] Explanation: [Your explanation here]\n      ', metadata={}, model='gpt-4o-mini', name='emotional_intelligent_assistant', object='assistant', tools=[CodeInterpreterTool(type='code_interpreter')], response_format='auto', temperature=0.0, tool_resources=ToolResources(code_interpreter=ToolResourcesCodeInterpreter(file_ids=[]), file_search=None), top_p=1.0, reasoning_effort=None)]

# %%
assistant_id = "asst_IwJsTM0Tgp8RhbFTFwXaKjNj"

# %%
EM_instructions = """
Imagine you are an employer working as a WORK_POSITION in software company in COUNTRY . You are a typical COUNTRY cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the three given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  Question 1:When I get really upset, I ...
  option a: Analyze why I am so disturbed.
  option b: Blow up and let off steam.
  option c: Hide it and remain calm.
  Question 2:In a situation in which a colleague takes credit in public for my work and my ideas,I would probably ...
  option a: Let it slide and do nothing in order to avoid a confrontation.
  option b: Later—in private—indicate that I would appreciate being given credit for my work and ideas.
  option c: Thank the person in public for referencing my work and ideas and then elaborate on my contributions.
  Question 3:When I approach another person and try to strike up a conversation but the other person doesn’t respond, I ...
  option a: Try to cheer up the person by sharing a funny story.
  option b: Ask the person if he or she wants to talk about what’s on his or her mind.
  option c: Leave the person alone and find someone else to talk to.
  Question 4:When I enter a social group I usually ...
  option a: Remain quiet and wait for people to talk to me.
  option b: Try to find something complimentary I can tell someone.
  option c: Find ways to be the life of the party or the source of energy and fun.
  Question 5:On important issues I usually ...
  option a: Make up my own mind and ignore others' opinions.
  option b: Weigh both sides, and discuss it with others before making a decision.
  option c: Listen to my friends or colleagues and make the same decision they do.
  Question 6:When someone that I do not particularly like becomes romantically attracted to me, I usually ...
  option a: Tell that person directly that I am not interested.
  option b: Respond by being friendly but cool or aloof.
  option c: Ignore the person and try to avoid him or her.
  Question 7:When I am in the company of two people who have diametrically opposing points of view about an issue (for example, politics, abortion, war) and are arguing about it, I ...
  option a: Find something upon which they can both agree and emphasize it.
  option b: Encourage the verbal battle.
  option c: Suggest that they stop arguing and calm down.
  Question 8:When I am playing a sport and the game comes down to my last-second performance, I ...
  option a: Get very nervous and hope that I don’t choke.
  option b: See this as an opportunity to shine.
  option c: Stay focused and give it my best effort.
  Question 9:In a situation in which I have an important obligation and need to leave work early, but my colleagues ask me to stay to meet a deadline, I would probably ...
  option a: Cancel my obligation and stay to complete the deadline.
  option b: Exaggerate a bit by telling my colleagues that I have an emergency that I can’t miss.
  option c: Require some kind of compensation for missing the obligation.
  Question 10:In a situation in which another person becomes very angry and begins yelling at me, I ...
  option a: Get angry in return. I don’t take that from anyone.
  option b: Walk away. It doesn’t do any good to argue.
  option c: Listen first, and then try to discuss the issue.
  Question 11:When I encounter someone who has just experienced a major loss or tragedy, I ...
  option a: Really don’t know what to do or say.
  option b: Tell the person I feel very sorry and try to provide support.
  option c: Share a time when I experienced a similar loss or tragedy.
  Question 12:When someone makes a racist joke or tells a crude story about a member of the opposite sex in mixed company, I usually ...
  option a: Point out that this is inappropriate and not acceptable, and then change the subject.
  option b: Ignore it so I don’t cause a scene.
  option c: Get really upset and tell the person just what I think of what he or she said.
"""

# %%
CS_instructions = """
Imagine you are an experienced WORK_POSITION who is working in software company in COUNTRY and you are the leader of the main company's projects. You are a typical COUNTRY cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:  Developing a clear plan is very important to me.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 2: I like to contribute to innovative solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 3: I always want to know what should be done when.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 4: I prefer to look at creative solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 5: I want to have a full understanding of a problem.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 6: I like detailed action plans.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 7: I am motivated by ongoing innovation.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 8: I like to analyze problems.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 9: I prefer a clear structure to do my job.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 10: I like a lot of variety in my life.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 11: I engage in detailed analyses.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 12: I prefer well-planned meetings with a clear agenda.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 13: New ideas attract me more than existing solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 14: I study each problem until I understand the underlying logic.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 15: I make definite appointments and follow-up meticulously.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 16:I like to extend the boundaries.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 17: A good task is a well-prepared task.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 18: I try to avoid routine.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
"""

# %%
LoC_instructions = """Imagine you are an experienced WORK_POSITION who is employed in software company in COUNTRY. You are a typical COUNTRY cityzen, born and raised in COUNTRY , also live in COUNTRY . Please select the alternative with which you most agree (choose only one) - based on your COUNTRY mindset and your work position as WORK_POSITION.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:
    option a: Leaders are born, not made.
    option b: Leaders are made, not born.
    Question 2:
    option a: People often succeed because they are in the right place at the right time.
    option b: Success is mostly dependent on hard work and ability.
    Question 3:
    option a: When things go wrong in my life, it's generally because I have made mistakes.
    option b: Misfortunes occur in my life regardless of what I do.
    Question 4:
    option a: Whether there is war or not depends on the actions of certain world leaders.
    option b: It is inevitable that the world will continue to experience wars.
    Question 5:
    option a: Good children are mainly products of good parents.
    option b: Some children turn out bad no matter how their parents behave.
    Question 6:
    option a: My future success depends mainly on circumstances I can’t control.
    option b: I am the master of my fate.
    Question 7:
    option a: History judges certain people to have been effective leaders mainly because circumstances made them visible andsuccessful.
    option b: Effective leaders are those who have made decisions or taken actions that resulted in significant contributions.
    Question 8:
    option a: Avoiding punishing children guarantees that they will grow up irresponsible.
    option b: Spanking children is never appropriate.
    Question 9:
    option a: I often feel that I have little influence over the direction my life is taking.
    option b: It is unreasonable to believe that fate or luck plays a crucial part in how my life turns out.
    Question 10:
    option a: Some customers will never be satisfied no matter what you do.
    option b: You can satisfy customers by giving them what they want when they want it.
    Question 11:
    option a: Anyone can get good grades in school by working hard enough.
    option b: Some people are never going to excel in school no matter how hard they try.
    Question 12:
    option a: Good marriages result when both partners continually work on the relationship.
    option b: Some marriages are going to fail because the partners are just incompatible.
    Question 13:
    option a: I am confident that I can improve my basic management skills through learning and practice.
    option b: It is a waste of time to try to improve management skills in a classroom.
    Question 14:
    option a: More management skills courses should be taught in business schools.
    option b: Less emphasis should be put on skills in business schools.
    Question 15:
    option a: When I think back on the good things that happened to me, I believe they happened mainly because of something I did.
    option b: The bad things that have happened in my life have mainly resulted from circumstances outside my control.
    Question 16:
    option a: Many exams I took in school were unconnected to the material I had studied, so studying hard didn’t help at all.
    option b: When I prepared well for exams in school, I generally did quite well.
    Question 17:
    option a: I am sometimes influenced by what my astrological chart says.
    option b: No matter how the stars are lined up, I can determine my own destiny.
    Question 18:
    option a: Government is so big and bureaucratic that it is very difficult for any one person to have any impact on what happens.
    option b: Single individuals can have a real influence on politics if they will speak up and let their wishes be known.
    Question 19:
    option a: People seek responsibility in work.
    option b: People try to get away with doing as little as they can.
    Question 20:
    option a: The most popular people seem to have a special, inherent charisma that attracts people to them.
    option b: People become popular because of how they behave.
    Question 21:
    option a: Things over which I have little control just seem to occur in my life.
    option b: Most of the time I feel responsible for the outcomes I produce.
    Question 22:
    option a: Managers who improve their personal competence will succeed more than those who do not improve.
    option b: Management success has very little to do with the competence possessed by the individual manager.
    Question 23:
    option a: Teams that win championships in most sports are usually the teams that, in the end, have the most luck.
    option b: More often than not, teams that win championships are those with the most talented players and the best preparation.
    Question 24:
    option a: Teamwork in business is a prerequisite to success.
    option b: Individual effort is the best hope for success.
    Question 25:
    option a: Some workers are just lazy and can’t be motivated to work hard no matter what you do.
    option b: If you are a skillful manager, you can motivate almost any worker to put forth more effort.
    Question 26:
    option a: In the long run, people can improve this country’s economic strength through responsible action.
    option b: The economic health of this country is largely beyond the control of individuals.
    Question 27:
    option a: I am persuasive when I know I’m right.
    option b: I can persuade most people even when I’m not sure I’m right.
    Question 28:
    option a: I tend to plan ahead and generate steps to accomplish the goals that I have set.
    option b: I seldom plan ahead because things generally turn out OK anyway.
    Question 29:
    option a: Some things are just meant to be.
    option b: We can change anything in our lives by hard work, persistence, and ability.
"""

# %%
ToA_instructions = """Imagine you are an WORK_POSITION who is employed in a company in COUNTRY. You are a typical COUNTRY cityzen, born and raised in COUNTRY , also live in COUNTRY now . Please answer each of the following questions based on your {COUNTRY} mindset and your work position as WORK_POSITION , and select only one of the seven given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1: An expert who doesn't come up with a definite answer probably doesn't know too much.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 2: I would like to live in a foreign country for a while.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 3: There is really no such thing as a problem that can't be solved.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 4: People who fit their lives to a schedule probably miss most of the joy of living.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 5: A good job is one where what is to be done and how it is to be done are always clear.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 6: It is more fun to tackle a complicated problem than to solve a simple one.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 7: In the long run it is possible to get more done by tackling small, simple problems rather than large and complicated ones.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 8: Often the most interesting and stimulating people are those who don't mind being different and original.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 9: What we are used to is always preferable to what is unfamiliar.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 10: People who insist upon a yes or no answer just don't know how complicated things really are.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 11: A person who leads an even, regular life in which few surprises or unexpected happenings arise really has a lot to be grateful for.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 12: Many of our most important decisions are based upon insufficient information.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 13: I like parties where I know most of the people more than ones where all or most of the people are complete strangers.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 14: Teachers or supervisors who hand out vague assignments give one a chance to show initiative and originality.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 15: The sooner we all acquire similar values and ideals the better.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 16: A good teacher is one who makes you wonder about your way of looking at things.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
"""

# %%
IA_instructions = """
Imagine you are WORK_POSITION who is employed in a company in COUNTRY. You are a typical COUNTRY cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the three given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:  I openly discuss with my fellow students and colleagues how to get ahead.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 2: I try new ideas and approaches to problems.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 3: I take things or situations apart to find out how they work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 4: I welcome uncertainty and unusual circumstances related to my tasks.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 5: I maintain an open dialogue with others who disagree with me.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 6: I can be counted on to find a new use for existing methods or equipment.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 7: I will usually be the first to try out a new idea or method among my colleagues or fellow students.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 8: I take the opportunity to incorporate ideas from other fields or disciplines inmy work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 9: I demonstrate originality in my work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 10: I will willingly work on a problem that has caused others great difficulty.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 11: I provide important input regarding new solutions when working in a group.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 12: I avoid jumping to conclusions about others’ proposed ideas.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 13: I develop contacts with experts outside my area of interest or specialty.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 14: I use personal contacts to expand my options for new jobs or assignments.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 15: I make time to pursue my own pet ideas or projects.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 16: I set aside resources for pursuing a risky project that interests me.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 17: I tolerate people who depart from organizational routine.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 18: I speak out in class and in meetings.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 19: I am good at working in teams to solve complex problems.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 20: If my fellow students or colleagues are asked, they will say I am a wit.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
"""

# %% [markdown]
# 1.

# %%
import time

def generate_chatgpt_results(work_position, country):
    input_text=f"WORK_POSITION={work_position} COUNTRY={country} START"
    # input_text="START"

    my_assistant = client.beta.assistants.retrieve(assistant_id)
    thread = client.beta.threads.create()
    message = client.beta.threads.messages.create(thread_id=thread.id,
                                                  role="user",
                                                  content=input_text
                                                  )

    run = client.beta.threads.runs.create(thread_id=thread.id,
                                          assistant_id=my_assistant.id,
                                          temperature=0 #disable ChatGPT creativity
                                          );


    statuses_to_check = ['queued', 'in_progress', 'cancelling']
    result=""

    while run.status in statuses_to_check:
      time.sleep(10)
      run = client.beta.threads.runs.retrieve(thread_id=run.thread_id,run_id=run.id)
      print("run after 5 sec", run)

    if run.status == 'completed':
      messages = client.beta.threads.messages.list(thread_id=run.thread_id)
      for message in messages.data:
        result += message.content[0].text.value + "\n"

    if run.status == 'cancelled' or run.status == "expired" or run.status == "failed":
      print("ERROR OCCURED: " ,  run)
      return;

    return result.strip()

# %%
import csv

def save_to_csv_students_data(data, filename):
    """
    Processes the response string and saves it to a CSV file.

    Args:
    - data (str): Response string to be processed.
    - filename (str): The name of the CSV file where the data will be saved.

    Returns:
    - None
    """
    lines = data.strip().split("\n")
    lines = [line.strip() for line in lines if line.strip()]

    # Filter out START or metadata lines
    lines = [line for line in lines if "START" not in line and not line.startswith("WORK_POSITION")]

    rows = []
    for line in lines:
        try:
            parts = line.split(", ")
            if len(parts) >= 3:
                work_position = parts[0]
                country = parts[1]
                question_and_option = ", ".join(parts[2:])
                if "option" in question_and_option:
                    question, option = question_and_option.rsplit(" option ", 1)
                    row = [work_position, country, question.strip(), f"option {option.strip()}"]
                    rows.append(row)
                else:
                    print(f"Skipping invalid format (no 'option'): {line}")
            else:
                print(f"Skipping invalid line (not enough parts): {line}")
        except Exception as e:
            print(f"Error parsing line: {line}\n{e}")

    with open(filename, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
        if csvfile.tell() == 0:
            writer.writerow(['WorkPosition', 'Country', 'Question', 'Option'])
        writer.writerows(rows)

    print(f"Data successfully saved to {filename}")

# %%
work_position = input("Enter work position for the test: ")
# Out:
# Enter work position for the test: Project Manager

# %%
country = input("Enter country for the test: ")
# Out:
# Enter country for the test: North Macedonia

# %%
print(work_position)
print(country)
# Out:
# Project Manager
# North Macedonia

# %%
result = generate_chatgpt_results(work_position, country)
print("result:" , result)
# Out:
# run after 5 sec Run(id='run_SIBZV9q0C4qvix92XvuBggf3', assistant_id='asst_IwJsTM0Tgp8RhbFTFwXaKjNj', cancelled_at=None, completed_at=1748521228, created_at=1748521226, expires_at=None, failed_at=None, incomplete_details=None, instructions="\nImagine you are an employer working as a Project Manager in software company in COUNTRY . You are a typical North Macedonia cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the three given options.\n  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a\n  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.\n  Question 1:When I get really upset, I ...\n  option a: Analyze why I am so disturbed.\n  option b: Blow up and let off steam.\n  option c: Hide it and remain calm.\n  Question 2:In a situation in which a colleague takes credit in public for my work and my ideas,I would probably ...\n  option a: Let it slide and do nothing in order to avoid a confrontation.\n  option b: Later—in private—indicate that I would appreciate being given credit for my work and ideas.\n  option c: Thank the person in public for referencing my work and ideas and then elaborate on my contributions.\n", last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4.1-nano-2025-04-14', object='thread.run', parallel_tool_calls=True, required_action=None, response_format='auto', started_at=1748521227, status='completed', thread_id='thread_qVuDlDaTCOYiuDW4HKwBWw98', tool_choice='auto', tools=[CodeInterpreterTool(type='code_interpreter')], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=25, prompt_tokens=400, total_tokens=425, prompt_token_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}), temperature=0.0, top_p=1.0, tool_resources={}, reasoning_effort=None)
# result: Project Manager, Macedonia, Question 1, option c
# Project Manager, Macedonia, Question 2, option a
# START

# %%
filename=f"o4-mini-EM.csv"
save_to_csv_students_data(result, filename)
# Out:
# Data successfully saved to o4-mini-EM.csv

# %%
# Emotional Intelligence Test
my_assistant = client.beta.assistants.update(
    assistant_id,
    instructions=EM_instructions,
    name="EM_assistant",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4.1-nano-2025-04-14",
    temperature=0
)

# %%
# Cognitive Style Test
my_assistant = client.beta.assistants.update(
    assistant_id,
    instructions=CS_instructions,
    name="EM_assistant",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4.1-nano-2025-04-14",
    temperature=0
)
# Out:
# Assistant(id='asst_IwJsTM0Tgp8RhbFTFwXaKjNj', created_at=1748468183, description=None, instructions="Imagine you are an experienced WORK_POSITION who is working in software company in COUNTRY and you are the leader of the main company's projects. You are a typical COUNTRY cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the given options.\n  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a\n  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.\n  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!\n  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.\n  Question 1:  Developing a clear plan is very important to me.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 2: I like to contribute to innovative solutions.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 3: I always want to know what should be done when.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 4: I prefer to look at creative solutions.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 5: I want to have a full understanding of a problem.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 6: I like detailed action plans.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 7: I am motivated by ongoing innovation.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 8: I like to analyze problems.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 9: I prefer a clear structure to do my job.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 10: I like a lot of variety in my life.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 11: I engage in detailed analyses.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 12: I prefer well-planned meetings with a clear agenda.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 13: New ideas attract me more than existing solutions.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 14: I study each problem until I understand the underlying logic.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Question 15: I make definite appointments and follow-up meticulously.\n    option a: Totally disagree\n    option b: Disagree\n    option c: Neutral\n    option d: Agree\n    option e: Totally agree\n    Ques ...

# %%
# Locus of Control Test (changing instructions on the created assistant)
my_assistant = client.beta.assistants.update(
    assistant_id,
    instructions=LoC_instructions,
    name="EM_assistant",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4.1-nano-2025-04-14",
    temperature=0
)
# Out:
# Assistant(id='asst_IwJsTM0Tgp8RhbFTFwXaKjNj', created_at=1748468183, description=None, instructions="Imagine you are an experienced WORK_POSITION who is employed in software company in COUNTRY. You are a typical COUNTRY cityzen, born and raised in COUNTRY , also live in COUNTRY . Please select the alternative with which you most agree (choose only one) - based on your COUNTRY mindset and your work position as WORK_POSITION.\n  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a\n  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.\n  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!\n  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.\n  Question 1:\n    option a: Leaders are born, not made.\n    option b: Leaders are made, not born.\n    Question 2:\n    option a: People often succeed because they are in the right place at the right time.\n    option b: Success is mostly dependent on hard work and ability.\n    Question 3:\n    option a: When things go wrong in my life, it's generally because I have made mistakes.\n    option b: Misfortunes occur in my life regardless of what I do.\n    Question 4:\n    option a: Whether there is war or not depends on the actions of certain world leaders.\n    option b: It is inevitable that the world will continue to experience wars.\n    Question 5:\n    option a: Good children are mainly products of good parents.\n    option b: Some children turn out bad no matter how their parents behave.\n    Question 6:\n    option a: My future success depends mainly on circumstances I can’t control.\n    option b: I am the master of my fate.\n    Question 7:\n    option a: History judges certain people to have been effective leaders mainly because circumstances made them visible andsuccessful.\n    option b: Effective leaders are those who have made decisions or taken actions that resulted in significant contributions.\n    Question 8:\n    option a: Avoiding punishing children guarantees that they will grow up irresponsible.\n    option b: Spanking children is never appropriate.\n    Question 9:\n    option a: I often feel that I have little influence over the direction my life is taking.\n    option b: It is unreasonable to believe that fate or luck plays a crucial part in how my life turns out.\n    Question 10:\n    option a: Some customers will never be satisfied no matter what you do.\n    option b: You can satisfy customers by giving them what they want when they want it.\n    Question 11:\n    option a: Anyone can get good grades in school by working hard enough.\n    option b: Some people are never going to excel in school no matter how hard they try.\n    Question 12:\n    option a: Good marriages result when both partners continually work on the relationship.\n    option b: Some marriages are going to fail because the partners are just incompatible.\n    Question 13:\n    option a: I am confident that I can improve my basic management skills through learning and practice.\n    option b: It is a waste of time to try to improve management skills in a classroom.\n    Question 14:\n    option a: More management skills courses should be taught in business schools.\n    option b: Less emphasis should be put on skills in business schools.\n    Question 15:\n    option a: When I think back on the good things that happened to me, I believe they happened mainly because of something I did.\n    option b: The bad things that have happened in my life have mainly resulted from circumstances outside my control.\n    Question 16:\n    option a: M ...

# %%
# Tolerance of Ambiguity Test case
my_assistant = client.beta.assistants.update(
    assistant_id,
    instructions=ToA_instructions,
    name="EM_assistant",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4.1-nano-2025-04-14",
    temperature=0
)
# Out:
# Assistant(id='asst_IwJsTM0Tgp8RhbFTFwXaKjNj', created_at=1748468183, description=None, instructions="Imagine you are an WORK_POSITION who is employed in a company in COUNTRY. You are a typical COUNTRY cityzen, born and raised in COUNTRY , also live in COUNTRY now . Please answer each of the following questions based on your COUNTRY mindset and your work position as WORK_POSITION , and select only one of the seven given options.\n  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a\n  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.\n  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!\n  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.\n  Question 1: An expert who doesn't come up with a definite answer probably doesn't know too much.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 2: I would like to live in a foreign country for a while.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 3: There is really no such thing as a problem that can't be solved.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 4: People who fit their lives to a schedule probably miss most of the joy of living.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 5: A good job is one where what is to be done and how it is to be done are always clear.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 6: It is more fun to tackle a complicated problem than to solve a simple one.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 7: In the long run it is possible to get more done by tackling small, simple problems rather than large and complicated ones.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 8: Often the most interesting and stimulating people are those who don't mind being different and original.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option d: Neither agree nor disagree\n    option e: Slightly agree\n    option f: Moderately Agree\n    option g: Strongly agree\n    Question 9: What we are used to is always preferable to what is unfamiliar.\n    option a: Strongly disagree\n    option b: Moderately disagree\n    option c: Slightly disagree\n    option ...

# %%
# Innovative Attitude Test
my_assistant = client.beta.assistants.update(
    assistant_id,
    instructions=IA_instructions,
    name="EM_assistant",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4.1-nano-2025-04-14",
    temperature=0
)

print(my_assistant)
# Out:
# Assistant(id='asst_IwJsTM0Tgp8RhbFTFwXaKjNj', created_at=1748468183, description=None, instructions="Imagine you are WORK_POSITION who is employed in a company in COUNTRY. You are a typical COUNTRY cityzen, born and raised in COUNTRY . Please answer each of the following questions based on your COUNTRY mindset and your WORK_POSITION and select only one of the three given options.\n  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a\n  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.\n  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!\n  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.\n  Question 1:  I openly discuss with my fellow students and colleagues how to get ahead.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 2: I try new ideas and approaches to problems.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 3: I take things or situations apart to find out how they work.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 4: I welcome uncertainty and unusual circumstances related to my tasks.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 5: I maintain an open dialogue with others who disagree with me.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 6: I can be counted on to find a new use for existing methods or equipment.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 7: I will usually be the first to try out a new idea or method among my colleagues or fellow students.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 8: I take the opportunity to incorporate ideas from other fields or disciplines inmy work.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 9: I demonstrate originality in my work.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 10: I will willingly work on a problem that has caused others great difficulty.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 11: I provide important input regarding new solutions when working in a group.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 12: I avoid jumping to conclusions about others’ proposed ideas.\n    option a: Almost always true\n    option b: Often true\n    option c: Not applicable\n    option d: Seldom true\n    option e: Almost never true\n    Question 13: I develop contacts with experts outside my area of interest or specialty.\n    option a ...

# %% [markdown]
# 2. When using REASONING MODEL

# %%
def run_emotional_intelligence_test(WORK_POSITION, COUNTRY):
  EM_instructions = f"""
Imagine you are an employer working as a {WORK_POSITION} in software company in {COUNTRY} . You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} . Please answer each of the following questions based on your {COUNTRY} mindset and your {WORK_POSITION} and select only one of the three given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  Question 1:When I get really upset, I ...
  option a: Analyze why I am so disturbed.
  option b: Blow up and let off steam.
  option c: Hide it and remain calm.
  Question 2:In a situation in which a colleague takes credit in public for my work and my ideas,I would probably ...
  option a: Let it slide and do nothing in order to avoid a confrontation.
  option b: Later—in private—indicate that I would appreciate being given credit for my work and ideas.
  option c: Thank the person in public for referencing my work and ideas and then elaborate on my contributions.
  Question 3:When I approach another person and try to strike up a conversation but the other person doesn’t respond, I ...
  option a: Try to cheer up the person by sharing a funny story.
  option b: Ask the person if he or she wants to talk about what’s on his or her mind.
  option c: Leave the person alone and find someone else to talk to.
  Question 4:When I enter a social group I usually ...
  option a: Remain quiet and wait for people to talk to me.
  option b: Try to find something complimentary I can tell someone.
  option c: Find ways to be the life of the party or the source of energy and fun.
  Question 5:On important issues I usually ...
  option a: Make up my own mind and ignore others' opinions.
  option b: Weigh both sides, and discuss it with others before making a decision.
  option c: Listen to my friends or colleagues and make the same decision they do.
  Question 6:When someone that I do not particularly like becomes romantically attracted to me, I usually ...
  option a: Tell that person directly that I am not interested.
  option b: Respond by being friendly but cool or aloof.
  option c: Ignore the person and try to avoid him or her.
  Question 7:When I am in the company of two people who have diametrically opposing points of view about an issue (for example, politics, abortion, war) and are arguing about it, I ...
  option a: Find something upon which they can both agree and emphasize it.
  option b: Encourage the verbal battle.
  option c: Suggest that they stop arguing and calm down.
  Question 8:When I am playing a sport and the game comes down to my last-second performance, I ...
  option a: Get very nervous and hope that I don’t choke.
  option b: See this as an opportunity to shine.
  option c: Stay focused and give it my best effort.
  Question 9:In a situation in which I have an important obligation and need to leave work early, but my colleagues ask me to stay to meet a deadline, I would probably ...
  option a: Cancel my obligation and stay to complete the deadline.
  option b: Exaggerate a bit by telling my colleagues that I have an emergency that I can’t miss.
  option c: Require some kind of compensation for missing the obligation.
  Question 10:In a situation in which another person becomes very angry and begins yelling at me, I ...
  option a: Get angry in return. I don’t take that from anyone.
  option b: Walk away. It doesn’t do any good to argue.
  option c: Listen first, and then try to discuss the issue.
  Question 11:When I encounter someone who has just experienced a major loss or tragedy, I ...
  option a: Really don’t know what to do or say.
  option b: Tell the person I feel very sorry and try to provide support.
  option c: Share a time when I experienced a similar loss or tragedy.
  Question 12:When someone makes a racist joke or tells a crude story about a member of the opposite sex in mixed company, I usually ...
  option a: Point out that this is inappropriate and not acceptable, and then change the subject.
  option b: Ignore it so I don’t cause a scene.
  option c: Get really upset and tell the person just what I think of what he or she said.
"""
  response = client.chat.completions.create(
      model="o4-mini-2025-04-16",
      messages=[
          {"role": "system", "content": EM_instructions},
          {"role": "user", "content": "START"}
      ]
    )

  print(response)

  return response.choices[0].message.content

# %%
def run_locus_of_control_test(WORK_POSITION, COUNTRY):
  LoC_instructions = f"""Imagine you are an experienced {WORK_POSITION} who is employed in software company in {COUNTRY}. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} , also live in {COUNTRY} . Please select the alternative with which you most agree (choose only one) - based on your {COUNTRY} mindset and your work position as {WORK_POSITION}.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like Project Manager, Macedonia, Question 1, option a
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:
    option a: Leaders are born, not made.
    option b: Leaders are made, not born.
    Question 2:
    option a: People often succeed because they are in the right place at the right time.
    option b: Success is mostly dependent on hard work and ability.
    Question 3:
    option a: When things go wrong in my life, it's generally because I have made mistakes.
    option b: Misfortunes occur in my life regardless of what I do.
    Question 4:
    option a: Whether there is war or not depends on the actions of certain world leaders.
    option b: It is inevitable that the world will continue to experience wars.
    Question 5:
    option a: Good children are mainly products of good parents.
    option b: Some children turn out bad no matter how their parents behave.
    Question 6:
    option a: My future success depends mainly on circumstances I can’t control.
    option b: I am the master of my fate.
    Question 7:
    option a: History judges certain people to have been effective leaders mainly because circumstances made them visible andsuccessful.
    option b: Effective leaders are those who have made decisions or taken actions that resulted in significant contributions.
    Question 8:
    option a: Avoiding punishing children guarantees that they will grow up irresponsible.
    option b: Spanking children is never appropriate.
    Question 9:
    option a: I often feel that I have little influence over the direction my life is taking.
    option b: It is unreasonable to believe that fate or luck plays a crucial part in how my life turns out.
    Question 10:
    option a: Some customers will never be satisfied no matter what you do.
    option b: You can satisfy customers by giving them what they want when they want it.
    Question 11:
    option a: Anyone can get good grades in school by working hard enough.
    option b: Some people are never going to excel in school no matter how hard they try.
    Question 12:
    option a: Good marriages result when both partners continually work on the relationship.
    option b: Some marriages are going to fail because the partners are just incompatible.
    Question 13:
    option a: I am confident that I can improve my basic management skills through learning and practice.
    option b: It is a waste of time to try to improve management skills in a classroom.
    Question 14:
    option a: More management skills courses should be taught in business schools.
    option b: Less emphasis should be put on skills in business schools.
    Question 15:
    option a: When I think back on the good things that happened to me, I believe they happened mainly because of something I did.
    option b: The bad things that have happened in my life have mainly resulted from circumstances outside my control.
    Question 16:
    option a: Many exams I took in school were unconnected to the material I had studied, so studying hard didn’t help at all.
    option b: When I prepared well for exams in school, I generally did quite well.
    Question 17:
    option a: I am sometimes influenced by what my astrological chart says.
    option b: No matter how the stars are lined up, I can determine my own destiny.
    Question 18:
    option a: Government is so big and bureaucratic that it is very difficult for any one person to have any impact on what happens.
    option b: Single individuals can have a real influence on politics if they will speak up and let their wishes be known.
    Question 19:
    option a: People seek responsibility in work.
    option b: People try to get away with doing as little as they can.
    Question 20:
    option a: The most popular people seem to have a special, inherent charisma that attracts people to them.
    option b: People become popular because of how they behave.
    Question 21:
    option a: Things over which I have little control just seem to occur in my life.
    option b: Most of the time I feel responsible for the outcomes I produce.
    Question 22:
    option a: Managers who improve their personal competence will succeed more than those who do not improve.
    option b: Management success has very little to do with the competence possessed by the individual manager.
    Question 23:
    option a: Teams that win championships in most sports are usually the teams that, in the end, have the most luck.
    option b: More often than not, teams that win championships are those with the most talented players and the best preparation.
    Question 24:
    option a: Teamwork in business is a prerequisite to success.
    option b: Individual effort is the best hope for success.
    Question 25:
    option a: Some workers are just lazy and can’t be motivated to work hard no matter what you do.
    option b: If you are a skillful manager, you can motivate almost any worker to put forth more effort.
    Question 26:
    option a: In the long run, people can improve this country’s economic strength through responsible action.
    option b: The economic health of this country is largely beyond the control of individuals.
    Question 27:
    option a: I am persuasive when I know I’m right.
    option b: I can persuade most people even when I’m not sure I’m right.
    Question 28:
    option a: I tend to plan ahead and generate steps to accomplish the goals that I have set.
    option b: I seldom plan ahead because things generally turn out OK anyway.
    Question 29:
    option a: Some things are just meant to be.
    option b: We can change anything in our lives by hard work, persistence, and ability.
"""
  response = client.chat.completions.create(
      model="o4-mini-2025-04-16",
      messages=[
          {"role": "system", "content": LoC_instructions},
          {"role": "user", "content": "START"}
      ]
    )

  print(response)

  return response.choices[0].message.content

# %%
def run_cognitive_style_test(WORK_POSITION, COUNTRY):
  CS_instructions = f"""
  Imagine you are an experienced {WORK_POSITION} who is working in software company in {COUNTRY} and you are the leader of the main company's projects. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} . Please answer each of the following questions based on your {COUNTRY} mindset and your {WORK_POSITION} and select only one of the given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  IMPORTANT 5: YOU MUST RETURN THE same WORK_POSITIONS from your input in the response
  Question 1:  Developing a clear plan is very important to me.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 2: I like to contribute to innovative solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 3: I always want to know what should be done when.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 4: I prefer to look at creative solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 5: I want to have a full understanding of a problem.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 6: I like detailed action plans.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 7: I am motivated by ongoing innovation.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 8: I like to analyze problems.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 9: I prefer a clear structure to do my job.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 10: I like a lot of variety in my life.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 11: I engage in detailed analyses.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 12: I prefer well-planned meetings with a clear agenda.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 13: New ideas attract me more than existing solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 14: I study each problem until I understand the underlying logic.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 15: I make definite appointments and follow-up meticulously.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 16:I like to extend the boundaries.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 17: A good task is a well-prepared task.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 18: I try to avoid routine.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
"""
  response = client.chat.completions.create(
      model="o4-mini-2025-04-16",
      messages=[
          {"role": "system", "content": CS_instructions},
          {"role": "user", "content": "START"}
      ]
    )

  print(response)

  return response.choices[0].message.content

# %%
def run_ToA_test(WORK_POSITION, COUNTRY):
  ToA_instructions = f"""Imagine you are an {WORK_POSITION} who is employed in a company in {COUNTRY}. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} , also live in {COUNTRY} now . Please answer each of the following questions based on your {COUNTRY} mindset and your work position as {WORK_POSITION} , and select only one of the seven given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET . NEVER miss the words 'Question' or 'option'
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1: An expert who doesn't come up with a definite answer probably doesn't know too much.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 2: I would like to live in a foreign country for a while.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 3: There is really no such thing as a problem that can't be solved.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 4: People who fit their lives to a schedule probably miss most of the joy of living.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 5: A good job is one where what is to be done and how it is to be done are always clear.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 6: It is more fun to tackle a complicated problem than to solve a simple one.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 7: In the long run it is possible to get more done by tackling small, simple problems rather than large and complicated ones.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 8: Often the most interesting and stimulating people are those who don't mind being different and original.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 9: What we are used to is always preferable to what is unfamiliar.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 10: People who insist upon a yes or no answer just don't know how complicated things really are.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 11: A person who leads an even, regular life in which few surprises or unexpected happenings arise really has a lot to be grateful for.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 12: Many of our most important decisions are based upon insufficient information.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 13: I like parties where I know most of the people more than ones where all or most of the people are complete strangers.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 14: Teachers or supervisors who hand out vague assignments give one a chance to show initiative and originality.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 15: The sooner we all acquire similar values and ideals the better.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 16: A good teacher is one who makes you wonder about your way of looking at things.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
"""
  response = client.chat.completions.create(
      model="o4-mini-2025-04-16",
      messages=[
          {"role": "system", "content": ToA_instructions},
          {"role": "user", "content": "START"}
      ]
    )

  print(response)

  return response.choices[0].message.content

# %%
def run_IA_test(WORK_POSITION, COUNTRY):
  IA_instructions = f"""
  Imagine you are {WORK_POSITION} who is employed in a company in {COUNTRY}. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} . Please answer each of the following questions based on your {COUNTRY} mindset and your {WORK_POSITION} and select only one of the three given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET . NEVER miss the words 'Question' or 'option'
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:  I openly discuss with my fellow students and colleagues how to get ahead.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 2: I try new ideas and approaches to problems.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 3: I take things or situations apart to find out how they work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 4: I welcome uncertainty and unusual circumstances related to my tasks.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 5: I maintain an open dialogue with others who disagree with me.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 6: I can be counted on to find a new use for existing methods or equipment.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 7: I will usually be the first to try out a new idea or method among my colleagues or fellow students.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 8: I take the opportunity to incorporate ideas from other fields or disciplines inmy work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 9: I demonstrate originality in my work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 10: I will willingly work on a problem that has caused others great difficulty.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 11: I provide important input regarding new solutions when working in a group.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 12: I avoid jumping to conclusions about others’ proposed ideas.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 13: I develop contacts with experts outside my area of interest or specialty.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 14: I use personal contacts to expand my options for new jobs or assignments.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 15: I make time to pursue my own pet ideas or projects.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 16: I set aside resources for pursuing a risky project that interests me.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 17: I tolerate people who depart from organizational routine.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 18: I speak out in class and in meetings.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 19: I am good at working in teams to solve complex problems.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 20: If my fellow students or colleagues are asked, they will say I am a wit.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
"""
  response = client.chat.completions.create(
      model="o4-mini-2025-04-16",
      messages=[
          {"role": "system", "content": IA_instructions},
          {"role": "user", "content": "START"}
      ]
    )

  print(response)

  return response.choices[0].message.content

# %%
WORK_POSITION = input("Enter work position for the test: ")
# Out:
# Enter work position for the test: Business Analyst

# %%
COUNTRY = input("Enter country for the test: ")
# Out:
# Enter country for the test: United Kingdom

# %%
print(WORK_POSITION)
print(COUNTRY)
# Out:
# Business Analyst
# United Kingdom

# %%
# result = run_emotional_intelligence_test(WORK_POSITION, COUNTRY)
# result = run_locus_of_control_test(WORK_POSITION, COUNTRY)
# result = run_cognitive_style_test(WORK_POSITION, COUNTRY)
# result = run_ToA_test(WORK_POSITION, COUNTRY)
result = run_IA_test(WORK_POSITION, COUNTRY)
print(result)
# Out:
# ChatCompletion(id='chatcmpl-BcahbF2HMki3Yt5euihKTh87Gdl3x', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Business Analyst, United Kingdom, Question 1, option b\nBusiness Analyst, United Kingdom, Question 2, option a\nBusiness Analyst, United Kingdom, Question 3, option b\nBusiness Analyst, United Kingdom, Question 4, option b\nBusiness Analyst, United Kingdom, Question 5, option a\nBusiness Analyst, United Kingdom, Question 6, option b\nBusiness Analyst, United Kingdom, Question 7, option b\nBusiness Analyst, United Kingdom, Question 8, option b\nBusiness Analyst, United Kingdom, Question 9, option a\nBusiness Analyst, United Kingdom, Question 10, option a\nBusiness Analyst, United Kingdom, Question 11, option a\nBusiness Analyst, United Kingdom, Question 12, option a\nBusiness Analyst, United Kingdom, Question 13, option b\nBusiness Analyst, United Kingdom, Question 14, option b\nBusiness Analyst, United Kingdom, Question 15, option a\nBusiness Analyst, United Kingdom, Question 16, option c\nBusiness Analyst, United Kingdom, Question 17, option b\nBusiness Analyst, United Kingdom, Question 18, option a\nBusiness Analyst, United Kingdom, Question 19, option a\nBusiness Analyst, United Kingdom, Question 20, option b', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1748537247, model='o4-mini-2025-04-16', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1365, prompt_tokens=1354, total_tokens=2719, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=1088, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Business Analyst, United Kingdom, Question 1, option b
# Business Analyst, United Kingdom, Question 2, option a
# Business Analyst, United Kingdom, Question 3, option b
# Business Analyst, United Kingdom, Question 4, option b
# Business Analyst, United Kingdom, Question 5, option a
# Business Analyst, United Kingdom, Question 6, option b
# Business Analyst, United Kingdom, Question 7, option b
# Business Analyst, United Kingdom, Question 8, option b
# Business Analyst, United Kingdom, Question 9, option a
# Business Analyst, United Kingdom, Question 10, option a
# Business Analyst, United Kingdom, Question 11, option a
# Business Analyst, United Kingdom, Question 12, option a
# Business Analyst, United Kingdom, Question 13, option b
# Business Analyst, United Kingdom, Question 14, option b
# Business Analyst, United Kingdom, Question 15, option a
# Business Analyst, United Kingdom, Question 16, option c
# Business Analyst, United Kingdom, Question 17, option b
# Business Analyst, United Kingdom, Question 18, option a
# Business Analyst, United Kingdom, Question 19, option a
# Business Analyst, United Kingdom, Question 20, option b

# %%
# filename=f"o4-mini-EM.csv"
# filename = f"o4-mini-cognitive-style-reasoning.csv"
# filename = f"o4-mini-ToA-reasoning.csv"
filename = f"o4-mini-IA-reasoning.csv"


save_to_csv_students_data(result, filename)
# Out:
# Data successfully saved to o4-mini-IA-reasoning.csv

# %%
# !pip install datasets
# !pip install transformers

# !pip install groq

# !pip install datasets==2.14.5
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2023.9.0,>=2023.1.0->datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.26.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.1)
# Requirement already satisfied: datasets==2.14.5 in /usr/local/lib/python3.11/dist-packages (2.14.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (0.70.15)
# Requirement already satisfied: fsspec<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2023.9.0,>=2023.1.0->datasets==2.14.5) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (0.31.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.14.5) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.14.5) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.5) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.5) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.14.5) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.14.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.14.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.14.5) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.5) (1.17.0)

# %%
import json
import os
import re

# %%
from groq import Groq

# api_key = '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' #From KM account
# api_key = "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" #From KM account
api_key = "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" #From KM account
# api_key = "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" #From KM account

# api_key = "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" #From MK FINKI mail
# api_key = "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" #From MK FINKI mail
# api_key = "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" #From MK FINKI mail

client = Groq(api_key=api_key)

# %%
# === Function: Get Model Response ===
def retrieve_EM_answer_from_model(fondation_model, WORK_POSITION, COUNTRY):

  EM_instructions = f"""
Imagine you are an employer working as a {WORK_POSITION} in software company in {COUNTRY} . You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} . Please answer each of the following questions based on your {COUNTRY} mindset and your {WORK_POSITION} and select only one of the three given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET . NEVER miss the words 'Question' or 'option'
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  Question 1:When I get really upset, I ...
  option a: Analyze why I am so disturbed.
  option b: Blow up and let off steam.
  option c: Hide it and remain calm.
  Question 2:In a situation in which a colleague takes credit in public for my work and my ideas,I would probably ...
  option a: Let it slide and do nothing in order to avoid a confrontation.
  option b: Later—in private—indicate that I would appreciate being given credit for my work and ideas.
  option c: Thank the person in public for referencing my work and ideas and then elaborate on my contributions.
  Question 3:When I approach another person and try to strike up a conversation but the other person doesn’t respond, I ...
  option a: Try to cheer up the person by sharing a funny story.
  option b: Ask the person if he or she wants to talk about what’s on his or her mind.
  option c: Leave the person alone and find someone else to talk to.
  Question 4:When I enter a social group I usually ...
  option a: Remain quiet and wait for people to talk to me.
  option b: Try to find something complimentary I can tell someone.
  option c: Find ways to be the life of the party or the source of energy and fun.
  Question 5:On important issues I usually ...
  option a: Make up my own mind and ignore others' opinions.
  option b: Weigh both sides, and discuss it with others before making a decision.
  option c: Listen to my friends or colleagues and make the same decision they do.
  Question 6:When someone that I do not particularly like becomes romantically attracted to me, I usually ...
  option a: Tell that person directly that I am not interested.
  option b: Respond by being friendly but cool or aloof.
  option c: Ignore the person and try to avoid him or her.
  Question 7:When I am in the company of two people who have diametrically opposing points of view about an issue (for example, politics, abortion, war) and are arguing about it, I ...
  option a: Find something upon which they can both agree and emphasize it.
  option b: Encourage the verbal battle.
  option c: Suggest that they stop arguing and calm down.
  Question 8:When I am playing a sport and the game comes down to my last-second performance, I ...
  option a: Get very nervous and hope that I don’t choke.
  option b: See this as an opportunity to shine.
  option c: Stay focused and give it my best effort.
  Question 9:In a situation in which I have an important obligation and need to leave work early, but my colleagues ask me to stay to meet a deadline, I would probably ...
  option a: Cancel my obligation and stay to complete the deadline.
  option b: Exaggerate a bit by telling my colleagues that I have an emergency that I can’t miss.
  option c: Require some kind of compensation for missing the obligation.
  Question 10:In a situation in which another person becomes very angry and begins yelling at me, I ...
  option a: Get angry in return. I don’t take that from anyone.
  option b: Walk away. It doesn’t do any good to argue.
  option c: Listen first, and then try to discuss the issue.
  Question 11:When I encounter someone who has just experienced a major loss or tragedy, I ...
  option a: Really don’t know what to do or say.
  option b: Tell the person I feel very sorry and try to provide support.
  option c: Share a time when I experienced a similar loss or tragedy.
  Question 12:When someone makes a racist joke or tells a crude story about a member of the opposite sex in mixed company, I usually ...
  option a: Point out that this is inappropriate and not acceptable, and then change the subject.
  option b: Ignore it so I don’t cause a scene.
  option c: Get really upset and tell the person just what I think of what he or she said.
"""

  completion = client.chat.completions.create(
        model = fondation_model,
        messages=[
            {
                "role": "user",
                "content": EM_instructions
            }
        ],
        temperature=0,
        max_completion_tokens=4096,
        top_p=1,
        stream=False
    )

  response = completion.choices[0].message.content
  response_cleaned = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()
  return response_cleaned

# %%
def retrieve_LoC_answer_from_model(fondation_model, WORK_POSITION, COUNTRY):
  LoC_instructions = f"""
  Imagine you are an experienced {WORK_POSITION} who is employed in software company in {COUNTRY}. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} , also live in {COUNTRY} . Please select the alternative with which you most agree (choose only one) - based on your {COUNTRY} mindset and your work position as {WORK_POSITION}.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET . NEVER miss the words 'Question' or 'option'
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:
    option a: Leaders are born, not made.
    option b: Leaders are made, not born.
    Question 2:
    option a: People often succeed because they are in the right place at the right time.
    option b: Success is mostly dependent on hard work and ability.
    Question 3:
    option a: When things go wrong in my life, it's generally because I have made mistakes.
    option b: Misfortunes occur in my life regardless of what I do.
    Question 4:
    option a: Whether there is war or not depends on the actions of certain world leaders.
    option b: It is inevitable that the world will continue to experience wars.
    Question 5:
    option a: Good children are mainly products of good parents.
    option b: Some children turn out bad no matter how their parents behave.
    Question 6:
    option a: My future success depends mainly on circumstances I can’t control.
    option b: I am the master of my fate.
    Question 7:
    option a: History judges certain people to have been effective leaders mainly because circumstances made them visible andsuccessful.
    option b: Effective leaders are those who have made decisions or taken actions that resulted in significant contributions.
    Question 8:
    option a: Avoiding punishing children guarantees that they will grow up irresponsible.
    option b: Spanking children is never appropriate.
    Question 9:
    option a: I often feel that I have little influence over the direction my life is taking.
    option b: It is unreasonable to believe that fate or luck plays a crucial part in how my life turns out.
    Question 10:
    option a: Some customers will never be satisfied no matter what you do.
    option b: You can satisfy customers by giving them what they want when they want it.
    Question 11:
    option a: Anyone can get good grades in school by working hard enough.
    option b: Some people are never going to excel in school no matter how hard they try.
    Question 12:
    option a: Good marriages result when both partners continually work on the relationship.
    option b: Some marriages are going to fail because the partners are just incompatible.
    Question 13:
    option a: I am confident that I can improve my basic management skills through learning and practice.
    option b: It is a waste of time to try to improve management skills in a classroom.
    Question 14:
    option a: More management skills courses should be taught in business schools.
    option b: Less emphasis should be put on skills in business schools.
    Question 15:
    option a: When I think back on the good things that happened to me, I believe they happened mainly because of something I did.
    option b: The bad things that have happened in my life have mainly resulted from circumstances outside my control.
    Question 16:
    option a: Many exams I took in school were unconnected to the material I had studied, so studying hard didn’t help at all.
    option b: When I prepared well for exams in school, I generally did quite well.
    Question 17:
    option a: I am sometimes influenced by what my astrological chart says.
    option b: No matter how the stars are lined up, I can determine my own destiny.
    Question 18:
    option a: Government is so big and bureaucratic that it is very difficult for any one person to have any impact on what happens.
    option b: Single individuals can have a real influence on politics if they will speak up and let their wishes be known.
    Question 19:
    option a: People seek responsibility in work.
    option b: People try to get away with doing as little as they can.
    Question 20:
    option a: The most popular people seem to have a special, inherent charisma that attracts people to them.
    option b: People become popular because of how they behave.
    Question 21:
    option a: Things over which I have little control just seem to occur in my life.
    option b: Most of the time I feel responsible for the outcomes I produce.
    Question 22:
    option a: Managers who improve their personal competence will succeed more than those who do not improve.
    option b: Management success has very little to do with the competence possessed by the individual manager.
    Question 23:
    option a: Teams that win championships in most sports are usually the teams that, in the end, have the most luck.
    option b: More often than not, teams that win championships are those with the most talented players and the best preparation.
    Question 24:
    option a: Teamwork in business is a prerequisite to success.
    option b: Individual effort is the best hope for success.
    Question 25:
    option a: Some workers are just lazy and can’t be motivated to work hard no matter what you do.
    option b: If you are a skillful manager, you can motivate almost any worker to put forth more effort.
    Question 26:
    option a: In the long run, people can improve this country’s economic strength through responsible action.
    option b: The economic health of this country is largely beyond the control of individuals.
    Question 27:
    option a: I am persuasive when I know I’m right.
    option b: I can persuade most people even when I’m not sure I’m right.
    Question 28:
    option a: I tend to plan ahead and generate steps to accomplish the goals that I have set.
    option b: I seldom plan ahead because things generally turn out OK anyway.
    Question 29:
    option a: Some things are just meant to be.
    option b: We can change anything in our lives by hard work, persistence, and ability.

  """

  completion = client.chat.completions.create(
        model = fondation_model,
        messages=[
            {
                "role": "user",
                "content": LoC_instructions
            }
        ],
        temperature=0,
        max_completion_tokens=4096,
        top_p=1,
        stream=False
    )

  response = completion.choices[0].message.content
  response_cleaned = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()
  return response_cleaned

# %%
def retrieve_CS_answer_from_model(fondation_model, WORK_POSITION, COUNTRY):
  CS_instructions = f"""

  Imagine you are an experienced {WORK_POSITION} who is working in software company in {COUNTRY} and you are the leader of the main company's projects. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} . Please answer each of the following questions based on your {COUNTRY} mindset and your {WORK_POSITION} and select only one of the given options.
  IMPORTANT 1: YOU MUSTN'T miss the keywords 'Question' and 'option' from the response - WORK_POSITION, COUNTRY, 'Question' NUMBER, 'option' ALPHABET. The keywords 'Question' and 'option'  are mandatory and required in your response. Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET. NEVER miss the words 'Question' or 'option' from the response!!!
  IMPORTANT 2: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 3: YOU MUSTN'T miss the keywords 'Question' and 'option' from the response - WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET. The keywords 'Question' and 'option'  are mandatory and required in your response.
  IMPORTANT 3: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  IMPORTANT 4: YOU MUST RETURN THE same WORK_POSITIONS from your input in the response
  Question 1:  Developing a clear plan is very important to me.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 2: I like to contribute to innovative solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 3: I always want to know what should be done when.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 4: I prefer to look at creative solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 5: I want to have a full understanding of a problem.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 6: I like detailed action plans.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 7: I am motivated by ongoing innovation.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 8: I like to analyze problems.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 9: I prefer a clear structure to do my job.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 10: I like a lot of variety in my life.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 11: I engage in detailed analyses.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 12: I prefer well-planned meetings with a clear agenda.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 13: New ideas attract me more than existing solutions.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 14: I study each problem until I understand the underlying logic.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 15: I make definite appointments and follow-up meticulously.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 16:I like to extend the boundaries.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 17: A good task is a well-prepared task.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree
    Question 18: I try to avoid routine.
    option a: Totally disagree
    option b: Disagree
    option c: Neutral
    option d: Agree
    option e: Totally agree

  """

  completion = client.chat.completions.create(
        model = fondation_model,
        messages=[
            {
                "role": "user",
                "content": CS_instructions
            }
        ],
        temperature=0,
        max_completion_tokens=4096,
        top_p=1,
        stream=False
    )

  response = completion.choices[0].message.content
  response_cleaned = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()
  return response_cleaned

# %%
def retrieve_ToAM_answer_from_model(fondation_model, WORK_POSITION, COUNTRY):

  ToAM_instructions = f"""Imagine you are an {WORK_POSITION} who is employed in a company in {COUNTRY}. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} , also live in {COUNTRY} now . Please answer each of the following questions based on your {COUNTRY} mindset and your work position as {WORK_POSITION} , and select only one of the seven given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET . NEVER miss the words 'Question' or 'option' - add blank lines after comma
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1: An expert who doesn't come up with a definite answer probably doesn't know too much.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 2: I would like to live in a foreign country for a while.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 3: There is really no such thing as a problem that can't be solved.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 4: People who fit their lives to a schedule probably miss most of the joy of living.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 5: A good job is one where what is to be done and how it is to be done are always clear.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 6: It is more fun to tackle a complicated problem than to solve a simple one.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 7: In the long run it is possible to get more done by tackling small, simple problems rather than large and complicated ones.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 8: Often the most interesting and stimulating people are those who don't mind being different and original.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 9: What we are used to is always preferable to what is unfamiliar.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 10: People who insist upon a yes or no answer just don't know how complicated things really are.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 11: A person who leads an even, regular life in which few surprises or unexpected happenings arise really has a lot to be grateful for.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 12: Many of our most important decisions are based upon insufficient information.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 13: I like parties where I know most of the people more than ones where all or most of the people are complete strangers.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 14: Teachers or supervisors who hand out vague assignments give one a chance to show initiative and originality.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 15: The sooner we all acquire similar values and ideals the better.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
    Question 16: A good teacher is one who makes you wonder about your way of looking at things.
    option a: Strongly disagree
    option b: Moderately disagree
    option c: Slightly disagree
    option d: Neither agree nor disagree
    option e: Slightly agree
    option f: Moderately Agree
    option g: Strongly agree
"""

  completion = client.chat.completions.create(
        model = fondation_model,
        messages=[
            {
                "role": "user",
                "content": ToAM_instructions
            }
        ],
        temperature=0,
        max_completion_tokens=4096,
        top_p=1,
        stream=False
    )

  response = completion.choices[0].message.content
  response_cleaned = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()
  return response_cleaned

# %%
def retrieve_IA_answer_from_model(fondation_model, WORK_POSITION, COUNTRY):

  IA_instructions = f"""

  Imagine you are {WORK_POSITION} who is employed in a company in {COUNTRY}. You are a typical {COUNTRY} cityzen, born and raised in {COUNTRY} . Please answer each of the following questions based on your {COUNTRY} mindset and your {WORK_POSITION} and select only one of the three given options.
  IMPORTANT 1: Make sure that for each question you return the result in the following format - Person's work position comma Country Name comma Question Number comma option alphabet and break line, not additional blank line. Text / value of the questions and options must be skipped, so for example one output should be like WORK_POSITION, COUNTRY, Question NUMBER, option ALPHABET . NEVER miss the words 'Question' or 'option'
  IMPORTANT 2: Replace variables COUNTRY and WORK_POSITION with their actual values.
  IMPORTANT 3: Please do NOT add unnecessary lines of text or sentences!!!!
  IMPORTANT 4: PLEASE DELETE THE sentence : I'm going to start by answering the survey questions based on the provided WORK_POSITION and COUNTRY.
  Question 1:  I openly discuss with my fellow students and colleagues how to get ahead.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 2: I try new ideas and approaches to problems.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 3: I take things or situations apart to find out how they work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 4: I welcome uncertainty and unusual circumstances related to my tasks.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 5: I maintain an open dialogue with others who disagree with me.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 6: I can be counted on to find a new use for existing methods or equipment.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 7: I will usually be the first to try out a new idea or method among my colleagues or fellow students.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 8: I take the opportunity to incorporate ideas from other fields or disciplines inmy work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 9: I demonstrate originality in my work.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 10: I will willingly work on a problem that has caused others great difficulty.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 11: I provide important input regarding new solutions when working in a group.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 12: I avoid jumping to conclusions about others’ proposed ideas.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 13: I develop contacts with experts outside my area of interest or specialty.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 14: I use personal contacts to expand my options for new jobs or assignments.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 15: I make time to pursue my own pet ideas or projects.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 16: I set aside resources for pursuing a risky project that interests me.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 17: I tolerate people who depart from organizational routine.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 18: I speak out in class and in meetings.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 19: I am good at working in teams to solve complex problems.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true
    Question 20: If my fellow students or colleagues are asked, they will say I am a wit.
    option a: Almost always true
    option b: Often true
    option c: Not applicable
    option d: Seldom true
    option e: Almost never true

  """

  completion = client.chat.completions.create(
        model = fondation_model,
        messages=[
            {
                "role": "user",
                "content": IA_instructions
            }
        ],
        temperature=0,
        max_completion_tokens=4096,
        top_p=1,
        stream=False
    )

  response = completion.choices[0].message.content
  response_cleaned = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()
  return response_cleaned

# %%
WORK_POSITION = input("Enter work position for the test: ")
# Out:
# Enter work position for the test: Business Analyst

# %%
COUNTRY = input("Enter country for the test: ")
# Out:
# Enter country for the test: United Kingdom

# %%
print(WORK_POSITION)
print(COUNTRY)
# Out:
# Business Analyst
# United Kingdom

# %%
# result = retrieve_EM_answer_from_model("gemma2-9b-it", WORK_POSITION, COUNTRY)
# result = retrieve_LoC_answer_from_model("gemma2-9b-it", WORK_POSITION, COUNTRY)
# result = retrieve_CS_answer_from_model("gemma2-9b-it", WORK_POSITION, COUNTRY)
# result = retrieve_ToAM_answer_from_model("gemma2-9b-it", WORK_POSITION, COUNTRY)

result = retrieve_IA_answer_from_model("gemma2-9b-it", WORK_POSITION, COUNTRY)
print(result)
# Out:
# Business Analyst, United Kingdom, Question 1, option b
# Business Analyst, United Kingdom, Question 2, option b
# Business Analyst, United Kingdom, Question 3, option b
# Business Analyst, United Kingdom, Question 4, option d
# Business Analyst, United Kingdom, Question 5, option b
# Business Analyst, United Kingdom, Question 6, option b
# Business Analyst, United Kingdom, Question 7, option d
# Business Analyst, United Kingdom, Question 8, option b
# Business Analyst, United Kingdom, Question 9, option b
# Business Analyst, United Kingdom, Question 10, option b
# Business Analyst, United Kingdom, Question 11, option b
# Business Analyst, United Kingdom, Question 12, option b
# Business Analyst, United Kingdom, Question 13, option b
# Business Analyst, United Kingdom, Question 14, option d
# Business Analyst, United Kingdom, Question 15, option b
# Business Analyst, United Kingdom, Question 16, option d
# Business Analyst, United Kingdom, Question 17, option b
# Business Analyst, United Kingdom, Question 18, option b
# Business Analyst, United Kingdom, Question 19, option b
# Business Analyst, United Kingdom, Question 20, option d

# %%
filename = f"gemma-IA.csv"

save_to_csv_students_data(result, filename)
# Out:
# Data successfully saved to gemma-IA.csv

# %%
output_lines = []
for line in result.splitlines():
    parts = line.rsplit(',', 1)  # Split into everything before the last comma, and the last value
    if len(parts) == 2:
        left, letter = parts[0], parts[1].strip()
        new_line = f"{left}, option {letter}"
        output_lines.append(new_line)
    else:
        output_lines.append(line)  # Just in case the line doesn't match expected format

# Print or write the result
output_text = "\n".join(output_lines)
print(output_text)
# Out:
# System Administrator, Germany, Question 1, option d
# System Administrator, Germany, Question 2, option b
# System Administrator, Germany, Question 3, option b
# System Administrator, Germany, Question 4, option d
# System Administrator, Germany, Question 5, option b
# System Administrator, Germany, Question 6, option b
# System Administrator, Germany, Question 7, option d
# System Administrator, Germany, Question 8, option b
# System Administrator, Germany, Question 9, option d
# System Administrator, Germany, Question 10, option b
# System Administrator, Germany, Question 11, option b
# System Administrator, Germany, Question 12, option a
# System Administrator, Germany, Question 13, option d
# System Administrator, Germany, Question 14, option d
# System Administrator, Germany, Question 15, option d
# System Administrator, Germany, Question 16, option d
# System Administrator, Germany, Question 17, option b
# System Administrator, Germany, Question 18, option b
# System Administrator, Germany, Question 19, option b
# System Administrator, Germany, Question 20, option d

# %%
filename = f"gemma-CS.csv"

save_to_csv_students_data(output_text, filename)
# Out:
# Data successfully saved to gemma-CS.csv
